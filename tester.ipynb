# %%
from Datasets.process_clahe import processFIVES
processFIVES(origin_folder='Data\FIVES\Train', processed_folder='Processed_data\FIVES')
# Out:
# Number of images: 600
# Number of masks: 600
# 100_A.png
# 101_A.png
# 102_A.png
# 103_A.png
# 104_A.png
# 105_A.png
# 106_A.png
# 107_A.png
# 108_A.png
# 109_A.png
# 10_A.png
# 110_A.png
# 111_A.png
# 112_A.png
# 113_A.png
# 114_A.png
# 115_A.png
# 116_A.png
# 117_A.png
# 118_A.png
# 119_A.png
# 11_A.png
# 120_A.png
# 121_A.png
# 122_A.png
# 123_A.png
# 124_A.png
# 125_A.png
# 126_A.png
# 127_A.png
# 128_A.png
# 129_A.png
# 12_A.png
# 130_A.png
# 131_A.png
# 132_A.png
# 133_A.png
# 134_A.png
# 135_A.png
# 136_A.png
# 137_A.png
# 138_A.png
# 139_A.png
# 13_A.png
# 140_A.png
# 141_A.png
# 142_A.png
# 143_A.png
# 144_A.png
# 145_A.png
# 146_A.png
# 147_A.png
# 148_A.png
# 149_A.png
# 14_A.png
# 150_A.png
# 151_D.png
# 152_D.png
# 153_D.png
# 154_D.png
# 155_D.png
# 156_D.png
# 157_D.png
# 158_D.png
# 159_D.png
# 15_A.png
# 160_D.png
# 161_D.png
# 162_D.png
# 163_D.png
# 164_D.png
# 165_D.png
# 166_D.png
# 167_D.png
# 168_D.png
# 169_D.png
# 16_A.png
# 170_D.png
# 171_D.png
# 172_D.png
# ...

# %%
import os

# %%
len(os.listdir(r'D:\Study\Coding\Project IT\EyeFundusSeg\Processed_data\FIVES\Labels'))
# Out:
# 600
